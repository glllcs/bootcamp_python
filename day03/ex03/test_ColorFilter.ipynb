# %%
from ColorFilter import ColorFilter
from ImageProcessor import ImageProcessor

# %%
cf = ColorFilter()
imp = ImageProcessor()

# %%
arr = imp.load('../resources/jpg_image.jpg')
imp.display(arr)
# Out:
# Loading image of dimensions 1244 x 700

# %%
imp.display(cf.invert(arr))

# %%
imp.display(cf.to_green(arr))

# %%
imp.display(cf.to_blue(arr))

# %%
imp.display(cf.to_red(arr))

# %%
imp.display(cf.to_celluloid(arr))

# %%
imp.display(cf.to_grayscale(arr, 'm'))

# %%
imp.display(cf.to_grayscale(arr, 'w'))

# %%
arr = imp.load('../resources/png_image.png')
imp.display(arr)
# Out:
# Loading image of dimensions 450 x 448

# %%
imp.display(cf.invert(arr))

# %%
imp.display(cf.to_green(arr))

# %%
imp.display(cf.to_blue(arr))

# %%
imp.display(cf.to_red(arr))

# %%
imp.display(cf.to_celluloid(arr))

# %%
imp.display(cf.to_grayscale(arr, 'm'))

# %%
imp.display(cf.to_grayscale(arr, 'w'))

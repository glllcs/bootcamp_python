# %%
import pandas as pd

# %%
df = pd.read_csv('../resources/athlete_events.csv')

# %%
row, col = df.shape

# %%
f'Loading dataset of dimensions {row} x {col}'
# Out:
# 'Loading dataset of dimensions 271116 x 15'

# %%
pd.DataFrame(df, index=range(4))
# Out:
#    ID                  Name Sex   Age  Height  Weight            Team  NOC  \
# 0   1             A Dijiang   M  24.0   180.0    80.0           China  CHN
# 1   2              A Lamusi   M  23.0   170.0    60.0           China  CHN
# 2   3   Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark  DEN
# 3   4  Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
#
#          Games  Year  Season       City       Sport  \
# 0  1992 Summer  1992  Summer  Barcelona  Basketball
# 1  2012 Summer  2012  Summer     London        Judo
# 2  1920 Summer  1920  Summer  Antwerpen    Football
# 3  1900 Summer  1900  Summer      Paris  Tug-Of-War
#
#                           Event Medal
# 0   Basketball Men's Basketball   NaN
# 1  Judo Men's Extra-Lightweight   NaN
# 2       Football Men's Football   NaN
# 3   Tug-Of-War Men's Tug-Of-War  Gold

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
n = 2004

# %%
males_year = df[(df['Year'] == n) & (df['Sex'] == 'M')]
males_year
# Out:
#             ID                              Name Sex   Age  Height  Weight  \
# 82          23                       Fritz Aanes   M  26.0   187.0    89.0
# 171         72  Aleksey Aleksandrovich Abalmasov   M  24.0   180.0    83.0
# 177         75                    Giorgos Abalof   M  22.0   178.0    70.0
# 183         81                   Georgios Abaris   M  22.0   190.0    77.0
# 186         84              Stephen Anthony Abas   M  26.0   165.0    55.0
# ...        ...                               ...  ..   ...     ...     ...
# 270981  135503                   Zurab Zviadauri   M  23.0   182.0    90.0
# 270984  135506                         Luka viej   M  23.0   185.0    90.0
# 271013  135522   Klaas Erik "Klaas-Erik" Zwering   M  23.0   189.0    80.0
# 271106  135565          Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271109  135567      Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
#
# ...

# %%
males_year['Age'].min()
# Out:
# 14.0

# %%
females_year = df[(df['Year'] == n) & (df['Sex'] == 'F')]
females_year
# Out:
#             ID                                       Name Sex   Age  Height  \
# 135         49                               Moonika Aava   F  24.0   168.0
# 195         90                  Tamila Rashidovna Abasova   F  21.0   163.0
# 196         90                  Tamila Rashidovna Abasova   F  21.0   163.0
# 202         95                          Georgia Abatzidou   F  35.0   155.0
# 311        165                        Nia Nicole Abdallah   F  20.0   175.0
# ...        ...                                        ...  ..   ...     ...
# 270971  135501  Ellina Aleksandrovna Zvereva (Kisheyeva-)   F  43.0   183.0
# 271009  135520                                Julia Zwehl   F  28.0   167.0
# 271033  135535                  Claudia Antoinette Zwiers   F  30.0   181.0
# 271099  135560                          Stavroula Zygouri   F  36.0   171.0
# 271103  135563                  Olesya Nikolayevna Zykina   F  23.0   171.0
#
# ...

# %%
df.drop_duplicates(subset=['ID', 'Year'], inplace=True)

# %%
# Out:
#    ID                      Name Sex   Age  Height  Weight         Team  NOC  \
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0  Netherlands  NED
#
#          Games  Year  Season         City          Sport  \
# 4  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  1992 Winter  1992  Winter  Albertville  Speed Skating
# 8  1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
#                               Event Medal
# 4  Speed Skating Women's 500 metres   NaN
# 6  Speed Skating Women's 500 metres   NaN
# 8  Speed Skating Women's 500 metres   NaN

# %%
def proportionBySport(df: pd.DataFrame, year: int, sport: str, gender: str, ) -> float:
    """
    The function returns a float corresponding to the proportion (percentage)
    of participants who played the given sport among the participants of the
    given gender.
    """
    df.drop_duplicates(subset=['ID', 'Year'], inplace=True)
    gender_in_year = df[(df['Sex'] == gender) & (df['Year'] == year)]
    gender_in_sport_in_year = gender_in_year[gender_in_year['Sport'] == sport]
    return len(gender_in_sport_in_year) / len(gender_in_year)

# %%
proportionBySport(df, 2004, 'Tennis', 'F')
# Out:
#             ID                                       Name Sex   Age  Height  \
# 135         49                               Moonika Aava   F  24.0   168.0
# 195         90                  Tamila Rashidovna Abasova   F  21.0   163.0
# 202         95                          Georgia Abatzidou   F  35.0   155.0
# 311        165                        Nia Nicole Abdallah   F  20.0   175.0
# 330        180                           Heba Abdel Gawad   F  22.0   154.0
# ...        ...                                        ...  ..   ...     ...
# 270971  135501  Ellina Aleksandrovna Zvereva (Kisheyeva-)   F  43.0   183.0
# 271009  135520                                Julia Zwehl   F  28.0   167.0
# 271033  135535                  Claudia Antoinette Zwiers   F  30.0   181.0
# 271099  135560                          Stavroula Zygouri   F  36.0   171.0
# 271103  135563                  Olesya Nikolayevna Zykina   F  23.0   171.0
#
# ...

# %%
proportionBySport(df, 1992, 'Cycling', 'M')
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 0            1                       A Dijiang   M  24.0   180.0    80.0
# 10           6                 Per Knut Aaland   M  31.0   188.0    75.0
# 18           7                    John Aalberg   M  31.0   183.0    72.0
# 59          20              Kjetil Andr Aamodt   M  20.0   176.0    85.0
# 96          33             Mika Lauri Aarnikka   M  24.0   187.0    76.0
# ...        ...                             ...  ..   ...     ...     ...
# 270892  135471              Jos Zurera Alberca   M  26.0   162.0    52.0
# 270960  135498                    Denis vegelj   M  20.0     NaN     NaN
# 271015  135523  Ronald Ferdinand "Ron" Zwerver   M  25.0   200.0    93.0
# 271035  135537      Sawomir Andrzej Zwierzyski   M  25.0   175.0    72.0
# 271048  135545                 Henk Jan Zwolle   M  27.0   197.0    93.0
#
#                  Team  NOC        Games  Year  Season         City  \
# ...

# %%
it = df[df['Name'] == 'Kjetil Andr Aamodt']

# %%
year_medal_dict = {}
for __, year in it['Year'].drop_duplicates().items():
    year_medal_dict[year] = {}
    medals = ('Gold', 'Silver', 'Bronze')
    for medal in medals:
        year_medal_dict[year][medal[0]] = len(it[(it['Year'] == year) & (it['Medal'] == medal)])
    return year_medal_dict
# Out:
#   File "<ipython-input-153-df70e9e89159>", line 7
#     return year_medal_dict
#     ^
# SyntaxError: 'return' outside function

# %%
for i in it:
    print(i)
# Out:
# ID
# Name
# Sex
# Age
# Height
# Weight
# Team
# NOC
# Games
# Year
# Season
# City
# Sport
# Event
# Medal

# %%
from typing import Dict

def howManyMedals(df: pd.DataFrame, name: 'str') -> Dict[int, Dict[str, int]]:
    """
    Returns a dictionary of dictionaries giving the number and type of medals
    for each year during which the participant won medals.
    """
    year_medal_dict = {}
    for __, year in it['Year'].drop_duplicates().items():
        year_medal_dict[year] = {}
        medals = ('Gold', 'Silver', 'Bronze')
        for medal in medals:
            year_medal_dict[year][medal[0]] = len(it[(it['Year'] == year) & (it['Medal'] == medal)])
    return year_medal_dict

# %%
di = {129:{'G':0,'S':0,'B':0}}

# %%
di
# Out:
# {129: {'G': 0, 'S': 0, 'B': 0}}

# %%
len(di.keys()) == 1
# Out:
# True

# %%
di.values()
# Out:
# dict_values([{'G': 0, 'S': 0, 'B': 0}])

# %%
di.values()['G']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-164-49c8e0b76af1> in <module>
# ----> 1 di.values()['G']
#
# TypeError: 'dict_values' object is not subscriptable

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-165-80124557cd02> in <module>
# ----> 1 __, player_years = player_df['Year'].drop_duplicates().items()
#
# NameError: name 'player_df' is not defined
